# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv",names=["combined_a"], header=None)

# %%
df
# Out:
#                                              combined_a
# 0      order_id | order_status    | customer        ...
# 1     +----------+-----------------+----------------...
# 2     |        3 | Order Finished  | Muhammed MacInt...
# 3     |      293 | Order Finished  | Barry French   ...
# 4     |      483 | Order Finished  | Clay Rozendal  ...
# ...                                                 ...
# 5497  |    52706 | Order Finished  | Paul Prost     ...
# 5498  |    54279 | Order Finished  | Lisa DeCherney ...
# 5499  |    55558 | Order Finished  | Philip Brown   ...
# 5500  |    56581 | Order Finished  | Lisa DeCherney ...
# 5501  +----------+-----------------+----------------...
#
# [5502 rows x 1 columns]

# %%
df = df['combined_a'].str.split("|",expand=True)
df
# Out:
#                                                      0                  1   \
# 0                                             order_id    order_status
# 1     +----------+-----------------+----------------...               None
# 2                                                                       3
# 3                                                                     293
# 4                                                                     483
# ...                                                 ...                ...
# 5497                                                                52706
# 5498                                                                54279
# 5499                                                                55558
# 5500                                                                56581
# 5501  +----------+-----------------+----------------...               None
#
#                             2                         3                 4   \
# 0      customer                              order_date    order_quantity
# 1                         None                      None              None
# 2             Order Finished     Muhammed MacIntyre            2010-10-13
# 3             Order Finished     Barry French                  2012-10-01
# 4             Order Finished     Clay Rozendal                 2011-07-10
# ...                        ...                       ...               ...
# 5497          Order Finished     Paul Prost                    2012-07-09
# 5498          Order Finished     Lisa DeCherney                2011-07-30
# 5499          Order Finished     Philip Brown                  2010-08-09
# 5500          Order Finished     Lisa DeCherney                2009-02-08
# 5501                      None                      None              None
#
#                     5            6                 7                   8   \
# 0           sales         discount    discount_value    product_category
# 1                 None         None              None                None
# 2                   6       523080              0.04               20923
# 3                  49     20246040              0.07             1417223
# 4                  30      9931519              0.08              794522
# ...                ...          ...               ...                 ...
# 5497               34      2083320              0.02               41666
# 5498               41     20142180               0.1             2014218
# 5499                8      2588080              0.05              129404
# 5500               20      4052020               0.1              405202
# 5501              None         None              None                None
#
#                                     9                                 10    11
# 0      product_sub_category                                               None
# 1                                 None                              None  None
# 2                    Office Supplies     Storage & Organization
# 3                    Office Supplies     Appliances
# 4                    Technology          Telephones and Communication
# ...                                ...                               ...   ...
# 5497                 Office Supplies     Binders and Binder Accessories
# 5498                 Technology          Office Machines
# 5499                 Furniture           Bookcases
# 5500                 Furniture           Office Furnishings
# 5501                              None                              None  None
#
# [5502 rows x 12 columns]

# %%
df = df.drop(11,axis=1)
df
# Out:
#                                                      0                  1   \
# 0                                             order_id    order_status
# 1     +----------+-----------------+----------------...               None
# 2                                                                       3
# 3                                                                     293
# 4                                                                     483
# ...                                                 ...                ...
# 5497                                                                52706
# 5498                                                                54279
# 5499                                                                55558
# 5500                                                                56581
# 5501  +----------+-----------------+----------------...               None
#
#                             2                         3                 4   \
# 0      customer                              order_date    order_quantity
# 1                         None                      None              None
# 2             Order Finished     Muhammed MacIntyre            2010-10-13
# 3             Order Finished     Barry French                  2012-10-01
# 4             Order Finished     Clay Rozendal                 2011-07-10
# ...                        ...                       ...               ...
# 5497          Order Finished     Paul Prost                    2012-07-09
# 5498          Order Finished     Lisa DeCherney                2011-07-30
# 5499          Order Finished     Philip Brown                  2010-08-09
# 5500          Order Finished     Lisa DeCherney                2009-02-08
# 5501                      None                      None              None
#
#                     5            6                 7                   8   \
# 0           sales         discount    discount_value    product_category
# 1                 None         None              None                None
# 2                   6       523080              0.04               20923
# 3                  49     20246040              0.07             1417223
# 4                  30      9931519              0.08              794522
# ...                ...          ...               ...                 ...
# 5497               34      2083320              0.02               41666
# 5498               41     20142180               0.1             2014218
# 5499                8      2588080              0.05              129404
# 5500               20      4052020               0.1              405202
# 5501              None         None              None                None
#
#                                     9                                 10
# 0      product_sub_category
# 1                                 None                              None
# 2                    Office Supplies     Storage & Organization
# 3                    Office Supplies     Appliances
# 4                    Technology          Telephones and Communication
# ...                                ...                               ...
# 5497                 Office Supplies     Binders and Binder Accessories
# 5498                 Technology          Office Machines
# 5499                 Furniture           Bookcases
# 5500                 Furniture           Office Furnishings
# 5501                              None                              None
#
# [5502 rows x 11 columns]

# %%
new_col = list(filter(lambda x : x != "",list(df.iloc[0].str.strip())))
new_df = pd.DataFrame(columns=new_col)
new_df
# Out:
# Empty DataFrame
# Columns: [order_id, order_status, customer, order_date, order_quantity, sales, discount, discount_value, product_category, product_sub_category]
# Index: []

# %%
drop_rows = [0,1,len(df) - 1]
df = df.drop(drop_rows, axis = 0)
df
# Out:
#      0           1                  2                         3   \
# 2                3    Order Finished     Muhammed MacIntyre
# 3              293    Order Finished     Barry French
# 4              483    Order Finished     Clay Rozendal
# 5              515    Order Finished     Carlos Soltero
# 6              613    Order Finished     Carl Jackson
# ...  ..         ...                ...                       ...
# 5496         47360    Order Finished     Philip Brown
# 5497         52706    Order Finished     Paul Prost
# 5498         54279    Order Finished     Lisa DeCherney
# 5499         55558    Order Finished     Philip Brown
# 5500         56581    Order Finished     Lisa DeCherney
#
#                 4                 5            6           7   \
# 2      2010-10-13                 6       523080        0.04
# 3      2012-10-01                49     20246040        0.07
# 4      2011-07-10                30      9931519        0.08
# 5      2010-08-28                19       788540        0.08
# 6      2011-06-17                12       187080        0.03
# ...            ...               ...          ...         ...
# 5496   2010-10-08                25      4401280        0.05
# 5497   2012-07-09                34      2083320        0.02
# 5498   2011-07-30                41     20142180         0.1
# 5499   2010-08-09                 8      2588080        0.05
# 5500   2009-02-08                20      4052020         0.1
#
#                     8                   9                                 10
# 2               20923    Office Supplies     Storage & Organization
# 3             1417223    Office Supplies     Appliances
# 4              794522    Technology          Telephones and Communication
# 5               63083    Office Supplies     Appliances
# 6                5612    Office Supplies     Binders and Binder Accessories
# ...                ...                 ...                               ...
# 5496           220064    Furniture           Chairs & Chairmats
# 5497            41666    Office Supplies     Binders and Binder Accessories
# 5498          2014218    Technology          Office Machines
# 5499           129404    Furniture           Bookcases
# 5500           405202    Furniture           Office Furnishings
#
# [5499 rows x 11 columns]

# %%
df = df.drop(0,axis = 1)
df
# Out:
#               1                  2                         3             4   \
# 2             3    Order Finished     Muhammed MacIntyre        2010-10-13
# 3           293    Order Finished     Barry French              2012-10-01
# 4           483    Order Finished     Clay Rozendal             2011-07-10
# 5           515    Order Finished     Carlos Soltero            2010-08-28
# 6           613    Order Finished     Carl Jackson              2011-06-17
# ...          ...                ...                       ...           ...
# 5496      47360    Order Finished     Philip Brown              2010-10-08
# 5497      52706    Order Finished     Paul Prost                2012-07-09
# 5498      54279    Order Finished     Lisa DeCherney            2011-07-30
# 5499      55558    Order Finished     Philip Brown              2010-08-09
# 5500      56581    Order Finished     Lisa DeCherney            2009-02-08
#
#                     5            6           7                 8   \
# 2                   6       523080        0.04             20923
# 3                  49     20246040        0.07           1417223
# 4                  30      9931519        0.08            794522
# 5                  19       788540        0.08             63083
# 6                  12       187080        0.03              5612
# ...                ...          ...         ...               ...
# 5496               25      4401280        0.05            220064
# 5497               34      2083320        0.02             41666
# 5498               41     20142180         0.1           2014218
# 5499                8      2588080        0.05            129404
# 5500               20      4052020         0.1            405202
#
#                       9                                 10
# 2      Office Supplies     Storage & Organization
# 3      Office Supplies     Appliances
# 4      Technology          Telephones and Communication
# 5      Office Supplies     Appliances
# 6      Office Supplies     Binders and Binder Accessories
# ...                  ...                               ...
# 5496   Furniture           Chairs & Chairmats
# 5497   Office Supplies     Binders and Binder Accessories
# 5498   Technology          Office Machines
# 5499   Furniture           Bookcases
# 5500   Furniture           Office Furnishings
#
# [5499 rows x 10 columns]

# %%
col_len = len(new_df.columns)

for i in range(col_len):
    new_df.iloc[:,i] = df.iloc[:,[i]]
    new_df

# %%
new_df['sales'] = new_df['sales'].astype(int)

# %%
new_df['new_discount'] = new_df['discount'].astype(float) * 100
new_df['discount'] = new_df['new_discount'].astype('int16')
new_df = new_df.drop("new_discount",axis=1)

# %%
new_df['order_quantity'] = new_df['order_quantity'].astype('int16')

# %%
new_df['order_date'] = pd.to_datetime(new_df['order_date'])

# %%
new_df['order_date'].dt.year
new_df['order_date'].dt.day
new_df['order_date'].dt.month
new_df['order_date'].dt.hour
new_df['order_date'].dt.day_name()
# Out:
# 2       Wednesday
# 3          Monday
# 4          Sunday
# 5        Saturday
# 6          Friday
#           ...
# 5496       Friday
# 5497       Monday
# 5498     Saturday
# 5499       Monday
# 5500       Sunday
# Name: order_date, Length: 5499, dtype: object

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5499 entries, 2 to 5500
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              5499 non-null   object
#  1   order_status          5499 non-null   object
#  2   customer              5499 non-null   object
#  3   order_date            5499 non-null   datetime64[ns]
#  4   order_quantity        5499 non-null   int16
#  5   sales                 5499 non-null   int64
#  6   discount              5499 non-null   int16
#  7   discount_value        5499 non-null   object
#  8   product_category      5499 non-null   object
#  9   product_sub_category  5499 non-null   object
# dtypes: datetime64[ns](1), int16(2), int64(1), object(6)
# memory usage: 408.1+ KB
