# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("stud.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Select the first 10 rows of the dataset.
df[:9]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# ...

# %%
# Display only gender, math score, and reading score columns for the first 15 rows.
df.loc[:,["math score","gender","reading score"]]
# Out:
#      math score  gender  reading score
# 0            72  female             72
# 1            69  female             90
# 2            90  female             95
# 3            47    male             57
# 4            76    male             78
# ..          ...     ...            ...
# 995          88  female             99
# 996          62    male             55
# 997          59  female             71
# 998          68  female             78
# 999          77  female             86
#
# [1000 rows x 3 columns]

# %%
# Retrieve the last 5 rows using iloc.
df[-5:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# Display every alternate row from the dataset using slicing.
df[::2]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Get all students who scored above 85 in math.
df.loc[df["math score"] > 85]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# 53     male        group D                 high school      standard
# ..      ...            ...                         ...           ...
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
# 979  female        group C          associate's degree      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Select students where gender is "female" and reading score is above 80.
df.loc[(df["gender"] == "female") | (df["reading score"] > 80)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Retrieve all students who completed the test preparation course.
df.loc[df["test preparation course"] == "completed"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Filter students who have "free/reduced" lunch and scored less than 60 in writing.
df.loc[(df["lunch"] == "free/reduced") & (df["writing score"] < 60) ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 948    male        group B            some high school  free/reduced
# 961  female        group D            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 988  female        group A            some high school  free/reduced
# 996    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Extract only math score and writing score columns using loc.
df.loc[:,["math score"]]
df.iloc[:,[5]]
# Out:
#      math score
# 0            72
# 1            69
# 2            90
# 3            47
# 4            76
# ..          ...
# 995          88
# 996          62
# 997          59
# 998          68
# 999          77
#
# [1000 rows x 1 columns]

# %%
# Select rows 50 to 60 and columns gender, lunch, and math score together.
df.loc[50:59,["gender","lunch","math score"]]
df.iloc[50:59,[0,3,5]]
# Out:
#     gender         lunch  math score
# 50    male      standard          53
# 51    male  free/reduced          77
# 52    male      standard          53
# 53    male      standard          88
# 54  female  free/reduced          71
# 55  female  free/reduced          33
# 56  female      standard          82
# 57    male      standard          52
# 58    male      standard          58

# %%
# Find students with math score between 70 and 90 (inclusive).
df.loc[df["math score"].between(70,90,inclusive='both')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Select students who belong to group A or group B and scored above 75 in reading.
df.loc[(df["race/ethnicity"].isin(["group A","group B"])) & (df["reading score"] > 75)]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# 12   female        group B                 high school  standard
# 77     male        group A           bachelor's degree  standard
# ..      ...            ...                         ...       ...
# 946    male        group B                 high school  standard
# 969  female        group B           bachelor's degree  standard
# 982    male        group B            some high school  standard
# 983  female        group A                some college  standard
# 991  female        group B            some high school  standard
#
#     test preparation course  math score  reading score  writing score
# 2                      none          90             95             93
# ...

# %%
# Display only male students who didn’t complete the test preparation course.
df.loc[(df["gender"] == 'male') & (df["test preparation course"] == "none")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# ..     ...            ...                         ...           ...
# 977   male        group C          associate's degree      standard
# 981   male        group D            some high school      standard
# 985   male        group A                 high school      standard
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
# Select top 10 rows and reverse them using indexing.
df.head(10).iloc[::-1]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 9  female        group B                 high school  free/reduced
# 8    male        group D                 high school  free/reduced
# 7    male        group B                some college  free/reduced
# 6  female        group B                some college      standard
# 5  female        group B          associate's degree      standard
# 4    male        group C                some college      standard
# 3    male        group A          associate's degree  free/reduced
# 2  female        group B             master's degree      standard
# 1  female        group C                some college      standard
# 0  female        group B           bachelor's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 9                    none          38             60             50
# 8               completed          64             64             67
# ...

# %%
# Retrieve the rows for students whose parents have a master's degree and scores in all subjects are above 80.
score_columns = ["math score", "reading score", "writing score"]
above_80 = df[score_columns].gt(80).all(axis=1)
df.loc[(df['parental level of education'] == "master's degree") & (above_80)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 106  female        group D             master's degree      standard
# 130    male        group D             master's degree      standard
# 164  female        group E             master's degree      standard
# 175  female        group C             master's degree      standard
# 377  female        group D             master's degree  free/reduced
# 604    male        group D             master's degree  free/reduced
# 618    male        group D             master's degree      standard
# 685  female        group E             master's degree      standard
# 713    male        group D             master's degree      standard
# 845    male        group E             master's degree      standard
# 846    male        group C             master's degree      standard
# 861  female        group E             master's degree  free/reduced
# ...
